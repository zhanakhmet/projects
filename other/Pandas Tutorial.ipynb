# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\zhana\\Downloads\\nyc_weather.csv")
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df['Temperature'].max()
# Out:
# 50

# %%
#which days it rains
df['EST'][df.Events == 'Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
#average wind speed
df.fillna(0, inplace=True)
df['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903

# %%
df.shape
# Out:
# (31, 11)

# %%
df.tail()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1      0
# 28               10           8.0               0           4      0
# 29               10           7.0               0           0      0
# 30               10           5.0               0           0      0
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df.EST # df['EST']
# Out:
# 0      1/1/2016
# 1      1/2/2016
# 2      1/3/2016
# 3      1/4/2016
# 4      1/5/2016
# 5      1/6/2016
# 6      1/7/2016
# 7      1/8/2016
# 8      1/9/2016
# 9     1/10/2016
# 10    1/11/2016
# 11    1/12/2016
# 12    1/13/2016
# 13    1/14/2016
# 14    1/15/2016
# 15    1/16/2016
# 16    1/17/2016
# 17    1/18/2016
# 18    1/19/2016
# 19    1/20/2016
# 20    1/21/2016
# 21    1/22/2016
# 22    1/23/2016
# 23    1/24/2016
# 24    1/25/2016
# 25    1/26/2016
# 26    1/27/2016
# 27    1/28/2016
# 28    1/29/2016
# 29    1/30/2016
# 30    1/31/2016
# Name: EST, dtype: object

# %%
#columns that we want to print
df[['Events', 'WindDirDegrees']]
# Out:
#       Events  WindDirDegrees
# 0          0             281
# 1          0             275
# 2          0             277
# 3          0             345
# 4          0             333
# 5          0             259
# 6          0             293
# 7          0              79
# 8       Rain              76
# 9       Rain             109
# 10         0             289
# 11         0             235
# 12         0             284
# 13         0             266
# 14         0             101
# 15      Rain             340
# 16  Fog-Snow             345
# 17      Snow             293
# 18         0             293
# 19         0             302
# 20         0             312
# 21      Snow              34
# 22  Fog-Snow              42
# 23      Snow             327
# 24         0             286
# 25         0             244
# 26      Rain             311
# 27         0             234
# 28         0             298
# 29         0             257
# 30         0             241

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     31.000000   31.000000       31.000000
# mean          9.193548      6.225806    3.129032      247.129032
# std           1.939405      3.422569    2.629853       92.308086
# min           1.000000      0.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df[df.Temperature >= 32]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# ...

# %%
df[df.Temperature >= df.Temperature.max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           0.0             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df
# Out:
#                    EST  DewPoint  Humidity  Sea Level PressureIn  \
# Temperature
# 38            1/1/2016        23        52                 30.03
# 36            1/2/2016        18        46                 30.02
# 40            1/3/2016        21        47                 29.86
# 25            1/4/2016         9        44                 30.05
# 20            1/5/2016        -3        41                 30.57
# 33            1/6/2016         4        35                 30.50
# 39            1/7/2016        11        33                 30.28
# 39            1/8/2016        29        64                 30.20
# 44            1/9/2016        38        77                 30.16
# 50           1/10/2016        46        71                 29.59
# 33           1/11/2016         8        37                 29.92
# 35           1/12/2016        15        53                 29.85
# 26           1/13/2016         4        42                 29.94
# ...

# %%
df.loc[14]
# Out:
# EST                     1/15/2016
# Temperature                    43
# DewPoint                       31
# Humidity                       62
# Sea Level PressureIn        29.82
# VisibilityMiles                 9
# WindSpeedMPH                  5.0
# PrecipitationIn                 T
# CloudCover                      2
# Events                          0
# WindDirDegrees                101
# Name: 14, dtype: object

# %%
df.set_index('Temperature', inplace=True) #without inplace=True it crates new DataFrame

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     Temperature        EST  DewPoint  Humidity  Sea Level PressureIn  \
# 0            38   1/1/2016        23        52                 30.03
# 1            36   1/2/2016        18        46                 30.02
# 2            40   1/3/2016        21        47                 29.86
# 3            25   1/4/2016         9        44                 30.05
# 4            20   1/5/2016        -3        41                 30.57
# 5            33   1/6/2016         4        35                 30.50
# 6            39   1/7/2016        11        33                 30.28
# 7            39   1/8/2016        29        64                 30.20
# 8            44   1/9/2016        38        77                 30.16
# 9            50  1/10/2016        46        71                 29.59
# 10           33  1/11/2016         8        37                 29.92
# 11           35  1/12/2016        15        53                 29.85
# 12           26  1/13/2016         4        42                 29.94
# ...

# %%
df1 =pd.read_csv("C:\\Users\\zhana\\Downloads\\nyc_weather111.csv")
df1.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df1['EST'] = pd.to_datetime(df1['EST'])
df1
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  2016-01-01           38        23        52                 30.03
# 1  2016-01-02           36        18        46                 30.02
# 2  2016-01-03           40        21        47                 29.86
# 3  2016-01-04           25         9        44                 30.05
# 4  2016-01-05           20        -3        41                 30.57
# 5  2016-01-06           33         4        35                 30.50
# 6  2016-01-07           39        11        33                 30.28
# 7  2016-01-08           39        29        64                 30.20
# 8  2016-01-09           44        38        77                 30.16
# 9  2016-01-10           50        46        71                 29.59
# 10 2016-01-11           33         8        37                 29.92
# 11 2016-01-12           35        15        53                 29.85
# 12 2016-01-13           26         4        42                 29.94
# ...

# %%
df2 = pd.read_csv("C:\\Users\\zhana\\Downloads\\nyc_weather111.csv")
df2
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df2['Events'].ffill(inplace=True)
df2
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df2.dtypes
# Out:
# EST                      object
# Temperature               int64
# DewPoint                  int64
# Humidity                  int64
# Sea Level PressureIn    float64
# VisibilityMiles           int64
# WindSpeedMPH            float64
# PrecipitationIn          object
# CloudCover                int64
# Events                   object
# WindDirDegrees            int64
# dtype: object

# %%
df2['EST'] = pd.to_datetime(df2['EST'])

# %%
df2
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  2016-01-01           38        23        52                 30.03
# 1  2016-01-02           36        18        46                 30.02
# 2  2016-01-03           40        21        47                 29.86
# 3  2016-01-04           25         9        44                 30.05
# 4  2016-01-05           20        -3        41                 30.57
# 5  2016-01-06           33         4        35                 30.50
# 6  2016-01-07           39        11        33                 30.28
# 7  2016-01-08           39        29        64                 30.20
# 8  2016-01-09           44        38        77                 30.16
# 9  2016-01-10           50        46        71                 29.59
# 10 2016-01-11           33         8        37                 29.92
# 11 2016-01-12           35        15        53                 29.85
# 12 2016-01-13           26         4        42                 29.94
# ...

# %%
df2.dropna(how='all')
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  2016-01-01           38        23        52                 30.03
# 1  2016-01-02           36        18        46                 30.02
# 2  2016-01-03           40        21        47                 29.86
# 3  2016-01-04           25         9        44                 30.05
# 4  2016-01-05           20        -3        41                 30.57
# 5  2016-01-06           33         4        35                 30.50
# 6  2016-01-07           39        11        33                 30.28
# 7  2016-01-08           39        29        64                 30.20
# 8  2016-01-09           44        38        77                 30.16
# 9  2016-01-10           50        46        71                 29.59
# 10 2016-01-11           33         8        37                 29.92
# 11 2016-01-12           35        15        53                 29.85
# 12 2016-01-13           26         4        42                 29.94
# ...

# %%
df2.set_index('EST')
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 2016-01-01           38        23        52                 30.03
# 2016-01-02           36        18        46                 30.02
# 2016-01-03           40        21        47                 29.86
# 2016-01-04           25         9        44                 30.05
# 2016-01-05           20        -3        41                 30.57
# 2016-01-06           33         4        35                 30.50
# 2016-01-07           39        11        33                 30.28
# 2016-01-08           39        29        64                 30.20
# 2016-01-09           44        38        77                 30.16
# 2016-01-10           50        46        71                 29.59
# 2016-01-11           33         8        37                 29.92
# 2016-01-12           35        15        53                 29.85
# 2016-01-13           26         4        42                 29.94
# ...

# %%
df2['Events'].replace(np.NaN, '-', inplace=True)

# %%
df2
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  2016-01-01           38        23        52                 30.03
# 1  2016-01-02           36        18        46                 30.02
# 2  2016-01-03           40        21        47                 29.86
# 3  2016-01-04           25         9        44                 30.05
# 4  2016-01-05           20        -3        41                 30.57
# 5  2016-01-06           33         4        35                 30.50
# 6  2016-01-07           39        11        33                 30.28
# 7  2016-01-08           39        29        64                 30.20
# 8  2016-01-09           44        38        77                 30.16
# 9  2016-01-10           50        46        71                 29.59
# 10 2016-01-11           33         8        37                 29.92
# 11 2016-01-12           35        15        53                 29.85
# 12 2016-01-13           26         4        42                 29.94
# ...

# %%
g = df2.groupby('Temperature')

# %%
g.max()
# Out:
#                    EST  DewPoint  Humidity  Sea Level PressureIn  \
# Temperature
# 20          2016-01-05        -3        41                 30.57
# 22          2016-01-19         3        42                 30.03
# 25          2016-01-18         9        53                 30.05
# 26          2016-01-23        21        78                 30.21
# 28          2016-01-24        11        53                 29.92
# 30          2016-01-14        12        47                 29.95
# 31          2016-01-21        11        45                 30.15
# 32          2016-01-20        15        49                 30.13
# 33          2016-01-11         8        37                 30.50
# 34          2016-01-30        18        54                 30.25
# 35          2016-01-12        15        53                 29.85
# 36          2016-01-29        23        66                 30.02
# 37          2016-01-28        20        51                 29.90
# ...
